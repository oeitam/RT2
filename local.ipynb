# %%
from itertools import *

c1 = combinations(range(0,24),4)
c2 = [x for x in list(c1) if len({0,1,2,3}.union(set(x))) == 8]
list(c2)
# Out:
# [(4, 5, 6, 7),
#  (4, 5, 6, 8),
#  (4, 5, 6, 9),
#  (4, 5, 6, 10),
#  (4, 5, 6, 11),
#  (4, 5, 6, 12),
#  (4, 5, 6, 13),
#  (4, 5, 6, 14),
#  (4, 5, 6, 15),
#  (4, 5, 6, 16),
#  (4, 5, 6, 17),
#  (4, 5, 6, 18),
#  (4, 5, 6, 19),
#  (4, 5, 6, 20),
#  (4, 5, 6, 21),
#  (4, 5, 6, 22),
#  (4, 5, 6, 23),
#  (4, 5, 7, 8),
#  (4, 5, 7, 9),
#  (4, 5, 7, 10),
#  (4, 5, 7, 11),
#  (4, 5, 7, 12),
#  (4, 5, 7, 13),
#  (4, 5, 7, 14),
#  (4, 5, 7, 15),
#  (4, 5, 7, 16),
#  (4, 5, 7, 17),
#  (4, 5, 7, 18),
#  (4, 5, 7, 19),
#  (4, 5, 7, 20),
#  (4, 5, 7, 21),
#  (4, 5, 7, 22),
#  (4, 5, 7, 23),
#  (4, 5, 8, 9),
#  (4, 5, 8, 10),
#  (4, 5, 8, 11),
#  (4, 5, 8, 12),
#  (4, 5, 8, 13),
#  (4, 5, 8, 14),
#  (4, 5, 8, 15),
#  (4, 5, 8, 16),
#  (4, 5, 8, 17),
#  (4, 5, 8, 18),
#  (4, 5, 8, 19),
#  (4, 5, 8, 20),
#  (4, 5, 8, 21),
#  (4, 5, 8, 22),
#  (4, 5, 8, 23),
#  (4, 5, 9, 10),
#  (4, 5, 9, 11),
#  (4, 5, 9, 12),
#  (4, 5, 9, 13),
#  (4, 5, 9, 14),
#  (4, 5, 9, 15),
#  (4, 5, 9, 16),
# ...

# %%
type(c1)
# Out:
# itertools.combinations

# %%
# the dictionary
d = {1:2, 3:4, 5:6, 7:8}

# the subset of keys I'm interested in
l = [1,5]
print({k:d[k] for k in l if k in d})
# Out:
# {1: 2, 5: 6}

# %%
[-1]*3
# Out:
# [-1, -1, -1]

# %%
l = list([-1,-2]*5)
print(l)
l.index(-2,2)
# Out:
# [-1, -2, -1, -2, -1, -2, -1, -2, -1, -2]
# 3
